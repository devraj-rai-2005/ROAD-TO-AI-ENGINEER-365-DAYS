# %%
import pandas as pd

# %%
df = pd.read_csv('training.csv')

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'fnlwgt', 'Education', 'Education_Num',
#        'Martial_Status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_Gain', 'Capital_Loss', 'Hours_per_week', 'Country', 'Target'],
#       dtype='object')

# %%
df['Target'].value_counts()
# Out:
# Target
# <=50K    22654
# >50K      7508
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Target'] = le.fit_transform(df['Target'])

# %%
df['Target'].value_counts()
# Out:
# Target
# 0    22654
# 1     7508
# Name: count, dtype: int64

# %%
counts = df['Martial_Status'].value_counts()

# Get the index (model names), wrap in quotes, and join by comma
quoted_models = ", ".join([f'"{m}"' for m in counts.index])
print(quoted_models)
# Out:
# " Married_civ_spouse", " Never_married", " Divorced", " Separated", " Widowed", " Married_spouse_absent", " Married_AF_spouse"
